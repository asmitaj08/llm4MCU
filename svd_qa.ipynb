# %% [markdown]
# given an svd file, generate questions based on the tags

# %%
import os 
import json
import io
import random

from tqdm import tqdm
from collections import defaultdict
from cmsis_svd.parser import SVDParser

# %%
config = {
    'svd_files' : 'cmsis-svd-data/data/',
    'db' : './chroma_db'
}

# %%
vendor_to_svd = defaultdict(list)
svd_to_vendor = {}
svd_to_content = {}

for root, dirs, files in os.walk(config['svd_files']):
    subdirs = root.split(os.sep)
    if len(subdirs) > 2:  # Ensure it's at least within a vendor's subdirectory
        vendor = subdirs[2]  # Get the vendor name
        # Collect full file paths for the vendor
        for file in files:
            if 'svd' in file:
                file_path = os.path.join(root, file)
                vendor_to_svd[vendor].append(file)
                with open(file_path, 'rb') as f:
                    content = f.read()
                
                svd_to_content[file] = content
            svd_to_vendor[file] = vendor

# %%
# convert svd to content to json or text using svd parser 
def svd_to_json(svd_content):
    if isinstance(svd_content, bytes):
        svd_content = svd_content.decode("utf-8")
    else:
        # saved as json string already in case accidentally rerun
        return svd_content

    # try:
    #     svd_file = io.StringIO(svd_content)
    #     parser = SVDParser.for_xml_file(svd_file)
    #     device = parser.get_device()
    # except Exception as e:
    #     # raise ValueError(f"Failed to parse SVD content: {e}")
    #     return None

    svd_file = io.StringIO(svd_content)
    parser = SVDParser.for_xml_file(svd_file)
    device = parser.get_device()

    device_dict = {
        "device": {
            "name": device.name,
            "description": device.description,
            "peripherals": []
        }
    }

    for peripheral in device.peripherals:
        peripheral_info = {
            "name": peripheral.name,
            "description": peripheral.description,
            "base_address": peripheral.base_address,
            "registers": []
        }

        for register in peripheral.registers:
            register_info = {
                "name": register.name,
                "address_offset": register.address_offset,
                "size": register.size,
                "description": register.description,
                "fields": []
            }

            for field in register.fields:
                field_info = {
                    "name": field.name,
                    "bit_offset": field.bit_offset,
                    "bit_width": field.bit_width,
                    "description": field.description
                }
                register_info["fields"].append(field_info)

            peripheral_info["registers"].append(register_info)

        device_dict["device"]["peripherals"].append(peripheral_info)

    return str(json.dumps(device_dict, indent=4))

# %%
test_svd = svd_to_json(svd_to_content['nrf52840.svd'])

# %%
test_svd_json = json.loads(test_svd)

# %%
test_svd_json['device'].keys()
# Out:
# dict_keys(['name', 'description', 'peripherals'])

# %%
peripherals = test_svd_json['device']['peripherals']

# %%
peripherals[0]['name']
# Out:
# 'FICR'

# %% [markdown]
# {"prompt": "Generate the SVD file for the nRF52840 microcontroller.", "completion": "<SVD XML content here>"}
# {"prompt": "List all peripherals and their base addresses for the STM32F103 microcontroller.", "completion": "Peripheral base addresses: GPIOA - 0x40010800, GPIOB - 0x40010C00, ..."}

# %%
peripherals_template = {
    "prompt": "List all the {tag}s for {name} microcontroller."
}

list_all_tags_from_parent_template = {
    "prompt": "List all the {tag}s of {parent_tag} for {name} microcontroller."
}

specific_tag_template = {
    "prompt": "What is the {tag} of {parent_tag} for {name} microcontroller?"
}

# %%
# device level questions 
def generate_template_questions(device):
    qa = []
    if "name" in device:
        name = device['name']
    else:
        return qa

    # basic: name, description, peripherals 
    qa.append({
        "prompt": "What is the description of {name} microcontroller".format(name=name),
        "completion": device['description']
    })
    
    qa.append({
        "prompt": peripherals_template["prompt"].format(tag="peripheral", name=name),
        "completion": ', '.join([peripheral['name'] for peripheral in device['peripherals']])
    })
    
    for peripheral in device['peripherals']:
        # for every peripheral, list names, descriptions, base_address, registers
        p_name = peripheral['name'] + " peripheral"
        qa.append({
            "prompt": specific_tag_template["prompt"].format(tag="description", parent_tag=p_name, name=name),
            "completion": peripheral['description']
        })
        qa.append({
            "prompt": specific_tag_template["prompt"].format(tag="base address", parent_tag=p_name, name=name),
            "completion": peripheral['base_address']
        })
        qa.append({
            "prompt": list_all_tags_from_parent_template["prompt"].format(tag="register", parent_tag=p_name, name=name),
            "completion": ', '.join([register['name'] for register in peripheral['registers']])
        })
        
        for register in peripheral["registers"]:
            r_name = register["name"] + " register from " + p_name
            
            qa.append({
                "prompt": specific_tag_template["prompt"].format(tag="description", parent_tag=r_name, name=name),
                "completion": register['description']
            })
            qa.append({
                "prompt": specific_tag_template["prompt"].format(tag="size", parent_tag=r_name, name=name),
                "completion": register['size']
            })
            qa.append({
                "prompt": specific_tag_template["prompt"].format(tag="address_offset", parent_tag=r_name, name=name),
                "completion": register['address_offset']
            })
            qa.append({
                "prompt": list_all_tags_from_parent_template["prompt"].format(tag="fields", parent_tag=r_name, name=name),
                "completion": ', '.join([field['name'] for field in register['fields']])
            })
            
            for field in register['fields']:
                f_name = field["name"] + " field from " + r_name
                
                qa.append({
                    "prompt": specific_tag_template["prompt"].format(tag="description", parent_tag=f_name, name=name),
                    "completion": register['description']
                })
                if "bit_offset" in register:
                    qa.append({
                        "prompt": specific_tag_template["prompt"].format(tag="bit_offset", parent_tag=f_name, name=name),
                        "completion": register['bit_offset']
                    })
                if "bit_width" in register:
                    qa.append({
                        "prompt": specific_tag_template["prompt"].format(tag="bit_width", parent_tag=f_name, name=name),
                        "completion": register['bit_width']
                    })
                
    return qa

# %%
test_out = generate_template_questions(test_svd_json['device'])

# %%
print(len(test_out))
# Out:
# 12111

# %%
all_svd_qa = []
# Out:
# 1798

# %%
print(len((list(svd_to_content.keys()))))
# choose 10 random svds to test the template qa generation
random_keys = random.sample(list(svd_to_content.keys()), 5)
subset_svds = {}

# Print the selected items
for key in random_keys:
    print(key)
    subset_svds[key] = svd_to_content[key]
    # print(f"Content: {svd_to_content[key]}")
# Out:
# 1798
# MB9AF31xK.svd
# TM4C1231H6PZ.svd
# EFM32LG900F256.svd
# EFM32GG11B820F2048GQ100.svd
# ATSAMD21J17A.svd

# %%
for svd_name, svd in tqdm(subset_svds.items()):
    # print(svd_name)
    svd_content = svd_to_json(svd)
    svd_json = json.loads(svd_content)
    svd_qa = generate_template_questions(svd_json['device'])
    all_svd_qa.extend(svd_qa)
# Out:
# 100%|██████████| 5/5 [00:01<00:00,  3.72it/s]

# %%
len(all_svd_qa)
# Out:
# 53988

# %%
all_svd_qa
# Out:
# [{'prompt': 'What is the description of MB9AF31xK microcontroller',
#   'completion': 'MB9AF31xK'},
#  {'prompt': 'List all the peripherals for MB9AF31xK microcontroller.',
#   'completion': 'WORKFLASH_IF, FLASH_IF, CRG, CRTRIM, SWWDT, HWWDT, DTIM, MFT0, BTIOSEL03, BTIOSEL47, SBSSR, BT0, BT1, BT2, BT3, BT4, BT5, BT6, BT7, QPRC0, WC, MFT_PPG, ADC0, ADC1, EXTI, INTREQ, GPIO, LVD, DS, MFS0, MFS1, MFS3, MFS5, MFS_NFC, RTC, CRC, USBCLK, USB0, DMAC'},
#  {'prompt': 'What is the description of WORKFLASH_IF peripheral for MB9AF31xK microcontroller?',
#   'completion': 'WorkFlash Memory'},
#  {'prompt': 'What is the base address of WORKFLASH_IF peripheral for MB9AF31xK microcontroller?',
#   'completion': 537788416},
#  {'prompt': 'List all the registers of WORKFLASH_IF peripheral for MB9AF31xK microcontroller.',
#   'completion': 'WFASZR, WFRWTR, WFSTR'},
#  {'prompt': 'What is the description of WFASZR register from WORKFLASH_IF peripheral for MB9AF31xK microcontroller?',
#   'completion': 'WorkFlash Access Size Register'},
#  {'prompt': 'What is the size of WFASZR register from WORKFLASH_IF peripheral for MB9AF31xK microcontroller?',
#   'completion': 32},
#  {'prompt': 'What is the address_offset of WFASZR register from WORKFLASH_IF peripheral for MB9AF31xK microcontroller?',
#   'completion': 0},
#  {'prompt': 'List all the fieldss of WFASZR register from WORKFLASH_IF peripheral for MB9AF31xK microcontroller.',
#   'completion': 'ASZ'},
#  {'prompt': 'What is the description of ASZ field from WFASZR register from WORKFLASH_IF peripheral for MB9AF31xK microcontroller?',
#   'completion': 'WorkFlash Access Size Register'},
#  {'prompt': 'What is the description of WFRWTR register from WORKFLASH_IF peripheral for MB9AF31xK microcontroller?',
#   'completion': 'WorkFlash Read Wait Register'},
#  {'prompt': 'What is the size of WFRWTR register from WORKFLASH_IF peripheral for MB9AF31xK microcontroller?',
#   'completion': 32},
#  {'prompt': 'What is the address_offset of WFRWTR register from WORKFLASH_IF peripheral for MB9AF31xK microcontroller?',
#   'completion': 4},
#  {'prompt': 'List all the fieldss of WFRWTR register from WORKFLASH_IF peripheral for MB9AF31xK microcontroller.',
#   'completion': 'RWT'},
#  {'prompt': 'What is the description of RWT field from WFRWTR register from WORKFLASH_IF peripheral for MB9AF31xK microcontroller?',
#   'completion': 'WorkFlash Read Wait Register'},
#  {'prompt': 'What is the description of WFSTR register from WORKFLASH_IF peripheral for MB9AF31xK microcontroller?',
#   'completion': 'WorkFlash Status Register'},
#  {'prompt': 'What is the size of WFSTR register from WORKFLASH_IF peripheral for MB9AF31xK microcontroller?',
#   'completion': 32},
#  {'prompt': 'What is the address_offset of WFSTR register from WORKFLASH_IF peripheral for MB9AF31xK microcontroller?',
#   'completion': 8},
#  {'prompt': 'List all the fieldss of WFSTR register from WORKFLASH_IF peripheral for MB9AF31xK microcontroller.',
#   'completion': 'HNG, RDY'},
#  {'prompt': 'What is the description of HNG field from WFSTR register from WORKFLASH_IF peripheral for MB9AF31xK microcontroller?',
#   'completion': 'WorkFlash Status Register'},
#  {'prompt': 'What is the description of RDY field from WFSTR register from WORKFLASH_IF peripheral for MB9AF31xK microcontroller?',
#   'completion': 'WorkFlash Status Register'},
#  {'prompt': 'What is the description of FLASH_IF peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Flash Memory'},
#  {'prompt': 'What is the base address of FLASH_IF peripheral for MB9AF31xK microcontroller?',
#   'completion': 1073741824},
#  {'prompt': 'List all the registers of FLASH_IF peripheral for MB9AF31xK microcontroller.',
#   'completion': 'FASZR, FRWTR, FSTR, FSYNDN, CRTRMM'},
#  {'prompt': 'What is the description of FASZR register from FLASH_IF peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Flash Access Size Register'},
#  {'prompt': 'What is the size of FASZR register from FLASH_IF peripheral for MB9AF31xK microcontroller?',
#   'completion': 32},
#  {'prompt': 'What is the address_offset of FASZR register from FLASH_IF peripheral for MB9AF31xK microcontroller?',
#   'completion': 0},
#  {'prompt': 'List all the fieldss of FASZR register from FLASH_IF peripheral for MB9AF31xK microcontroller.',
#   'completion': 'ASZ'},
#  {'prompt': 'What is the description of ASZ field from FASZR register from FLASH_IF peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Flash Access Size Register'},
#  {'prompt': 'What is the description of FRWTR register from FLASH_IF peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Flash Read Wait Register'},
#  {'prompt': 'What is the size of FRWTR register from FLASH_IF peripheral for MB9AF31xK microcontroller?',
#   'completion': 32},
#  {'prompt': 'What is the address_offset of FRWTR register from FLASH_IF peripheral for MB9AF31xK microcontroller?',
#   'completion': 4},
#  {'prompt': 'List all the fieldss of FRWTR register from FLASH_IF peripheral for MB9AF31xK microcontroller.',
#   'completion': 'RWT'},
#  {'prompt': 'What is the description of RWT field from FRWTR register from FLASH_IF peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Flash Read Wait Register'},
#  {'prompt': 'What is the description of FSTR register from FLASH_IF peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Flash Status Register'},
#  {'prompt': 'What is the size of FSTR register from FLASH_IF peripheral for MB9AF31xK microcontroller?',
#   'completion': 32},
#  {'prompt': 'What is the address_offset of FSTR register from FLASH_IF peripheral for MB9AF31xK microcontroller?',
#   'completion': 8},
#  {'prompt': 'List all the fieldss of FSTR register from FLASH_IF peripheral for MB9AF31xK microcontroller.',
#   'completion': 'ERR, HNG, RDY'},
#  {'prompt': 'What is the description of ERR field from FSTR register from FLASH_IF peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Flash Status Register'},
#  {'prompt': 'What is the description of HNG field from FSTR register from FLASH_IF peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Flash Status Register'},
#  {'prompt': 'What is the description of RDY field from FSTR register from FLASH_IF peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Flash Status Register'},
#  {'prompt': 'What is the description of FSYNDN register from FLASH_IF peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Flash Sync Down Register'},
#  {'prompt': 'What is the size of FSYNDN register from FLASH_IF peripheral for MB9AF31xK microcontroller?',
#   'completion': 32},
#  {'prompt': 'What is the address_offset of FSYNDN register from FLASH_IF peripheral for MB9AF31xK microcontroller?',
#   'completion': 16},
#  {'prompt': 'List all the fieldss of FSYNDN register from FLASH_IF peripheral for MB9AF31xK microcontroller.',
#   'completion': 'SD'},
#  {'prompt': 'What is the description of SD field from FSYNDN register from FLASH_IF peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Flash Sync Down Register'},
#  {'prompt': 'What is the description of CRTRMM register from FLASH_IF peripheral for MB9AF31xK microcontroller?',
#   'completion': 'CR Trimming Data Mirror Register'},
#  {'prompt': 'What is the size of CRTRMM register from FLASH_IF peripheral for MB9AF31xK microcontroller?',
#   'completion': 32},
#  {'prompt': 'What is the address_offset of CRTRMM register from FLASH_IF peripheral for MB9AF31xK microcontroller?',
#   'completion': 256},
#  {'prompt': 'List all the fieldss of CRTRMM register from FLASH_IF peripheral for MB9AF31xK microcontroller.',
#   'completion': 'TRMM'},
#  {'prompt': 'What is the description of TRMM field from CRTRMM register from FLASH_IF peripheral for MB9AF31xK microcontroller?',
#   'completion': 'CR Trimming Data Mirror Register'},
#  {'prompt': 'What is the description of CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Clock Unit Registers'},
#  {'prompt': 'What is the base address of CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 1073807360},
#  {'prompt': 'List all the registers of CRG peripheral for MB9AF31xK microcontroller.',
#   'completion': 'SCM_CTL, SCM_STR, BSC_PSR, APBC0_PSR, APBC1_PSR, APBC2_PSR, SWC_PSR, TTC_PSR, CSW_TMR, PSW_TMR, PLL_CTL1, PLL_CTL2, DBWDT_CTL, INT_ENR, INT_STR, INT_CLR, RST_STR, STB_CTL, CSV_CTL, CSV_STR, FCSWH_CTL, FCSWL_CTL, FCSWD_CTL'},
#  {'prompt': 'What is the description of SCM_CTL register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'System Clock Mode Control Register'},
#  {'prompt': 'What is the size of SCM_CTL register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 8},
#  {'prompt': 'What is the address_offset of SCM_CTL register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 0},
#  {'prompt': 'List all the fieldss of SCM_CTL register from CRG peripheral for MB9AF31xK microcontroller.',
#   'completion': 'RCS, PLLE, SOSCE, MOSCE'},
#  {'prompt': 'What is the description of RCS field from SCM_CTL register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'System Clock Mode Control Register'},
#  {'prompt': 'What is the description of PLLE field from SCM_CTL register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'System Clock Mode Control Register'},
#  {'prompt': 'What is the description of SOSCE field from SCM_CTL register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'System Clock Mode Control Register'},
#  {'prompt': 'What is the description of MOSCE field from SCM_CTL register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'System Clock Mode Control Register'},
#  {'prompt': 'What is the description of SCM_STR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'System Clock Mode Status Register'},
#  {'prompt': 'What is the size of SCM_STR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 8},
#  {'prompt': 'What is the address_offset of SCM_STR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 4},
#  {'prompt': 'List all the fieldss of SCM_STR register from CRG peripheral for MB9AF31xK microcontroller.',
#   'completion': 'RCM, PLRDY, SORDY, MORDY'},
#  {'prompt': 'What is the description of RCM field from SCM_STR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'System Clock Mode Status Register'},
#  {'prompt': 'What is the description of PLRDY field from SCM_STR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'System Clock Mode Status Register'},
#  {'prompt': 'What is the description of SORDY field from SCM_STR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'System Clock Mode Status Register'},
#  {'prompt': 'What is the description of MORDY field from SCM_STR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'System Clock Mode Status Register'},
#  {'prompt': 'What is the description of BSC_PSR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Base Clock Prescaler Register'},
#  {'prompt': 'What is the size of BSC_PSR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 8},
#  {'prompt': 'What is the address_offset of BSC_PSR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 16},
#  {'prompt': 'List all the fieldss of BSC_PSR register from CRG peripheral for MB9AF31xK microcontroller.',
#   'completion': 'BSR'},
#  {'prompt': 'What is the description of BSR field from BSC_PSR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Base Clock Prescaler Register'},
#  {'prompt': 'What is the description of APBC0_PSR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'APB0 Prescaler Register'},
#  {'prompt': 'What is the size of APBC0_PSR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 8},
#  {'prompt': 'What is the address_offset of APBC0_PSR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 20},
#  {'prompt': 'List all the fieldss of APBC0_PSR register from CRG peripheral for MB9AF31xK microcontroller.',
#   'completion': 'APBC0'},
#  {'prompt': 'What is the description of APBC0 field from APBC0_PSR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'APB0 Prescaler Register'},
#  {'prompt': 'What is the description of APBC1_PSR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'APB1 Prescaler Register'},
#  {'prompt': 'What is the size of APBC1_PSR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 8},
#  {'prompt': 'What is the address_offset of APBC1_PSR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 24},
#  {'prompt': 'List all the fieldss of APBC1_PSR register from CRG peripheral for MB9AF31xK microcontroller.',
#   'completion': 'APBC1EN, APBC1RST, APBC1'},
#  {'prompt': 'What is the description of APBC1EN field from APBC1_PSR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'APB1 Prescaler Register'},
#  {'prompt': 'What is the description of APBC1RST field from APBC1_PSR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'APB1 Prescaler Register'},
#  {'prompt': 'What is the description of APBC1 field from APBC1_PSR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'APB1 Prescaler Register'},
#  {'prompt': 'What is the description of APBC2_PSR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'APB2 Prescaler Register'},
#  {'prompt': 'What is the size of APBC2_PSR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 8},
#  {'prompt': 'What is the address_offset of APBC2_PSR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 28},
#  {'prompt': 'List all the fieldss of APBC2_PSR register from CRG peripheral for MB9AF31xK microcontroller.',
#   'completion': 'APBC2EN, APBC2RST, APBC2'},
#  {'prompt': 'What is the description of APBC2EN field from APBC2_PSR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'APB2 Prescaler Register'},
#  {'prompt': 'What is the description of APBC2RST field from APBC2_PSR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'APB2 Prescaler Register'},
#  {'prompt': 'What is the description of APBC2 field from APBC2_PSR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'APB2 Prescaler Register'},
#  {'prompt': 'What is the description of SWC_PSR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Software Watchdog Clock Prescaler Register'},
#  {'prompt': 'What is the size of SWC_PSR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 8},
#  {'prompt': 'What is the address_offset of SWC_PSR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 32},
#  {'prompt': 'List all the fieldss of SWC_PSR register from CRG peripheral for MB9AF31xK microcontroller.',
#   'completion': 'TESTB, SWDS'},
#  {'prompt': 'What is the description of TESTB field from SWC_PSR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Software Watchdog Clock Prescaler Register'},
#  {'prompt': 'What is the description of SWDS field from SWC_PSR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Software Watchdog Clock Prescaler Register'},
#  {'prompt': 'What is the description of TTC_PSR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Trace Clock Prescaler Register'},
#  {'prompt': 'What is the size of TTC_PSR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 8},
#  {'prompt': 'What is the address_offset of TTC_PSR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 40},
#  {'prompt': 'List all the fieldss of TTC_PSR register from CRG peripheral for MB9AF31xK microcontroller.',
#   'completion': 'TTC'},
#  {'prompt': 'What is the description of TTC field from TTC_PSR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Trace Clock Prescaler Register'},
#  {'prompt': 'What is the description of CSW_TMR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Clock Stabilization Wait Time Register'},
#  {'prompt': 'What is the size of CSW_TMR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 8},
#  {'prompt': 'What is the address_offset of CSW_TMR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 48},
#  {'prompt': 'List all the fieldss of CSW_TMR register from CRG peripheral for MB9AF31xK microcontroller.',
#   'completion': 'SOWT, MOWT'},
#  {'prompt': 'What is the description of SOWT field from CSW_TMR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Clock Stabilization Wait Time Register'},
#  {'prompt': 'What is the description of MOWT field from CSW_TMR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Clock Stabilization Wait Time Register'},
#  {'prompt': 'What is the description of PSW_TMR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'PLL Clock Stabilization Wait Time Setup Register'},
#  {'prompt': 'What is the size of PSW_TMR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 8},
#  {'prompt': 'What is the address_offset of PSW_TMR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 52},
#  {'prompt': 'List all the fieldss of PSW_TMR register from CRG peripheral for MB9AF31xK microcontroller.',
#   'completion': 'PINC, POWT'},
#  {'prompt': 'What is the description of PINC field from PSW_TMR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'PLL Clock Stabilization Wait Time Setup Register'},
#  {'prompt': 'What is the description of POWT field from PSW_TMR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'PLL Clock Stabilization Wait Time Setup Register'},
#  {'prompt': 'What is the description of PLL_CTL1 register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'PLL Control Register 1'},
#  {'prompt': 'What is the size of PLL_CTL1 register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 8},
#  {'prompt': 'What is the address_offset of PLL_CTL1 register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 56},
#  {'prompt': 'List all the fieldss of PLL_CTL1 register from CRG peripheral for MB9AF31xK microcontroller.',
#   'completion': 'PLLK, PLLM'},
#  {'prompt': 'What is the description of PLLK field from PLL_CTL1 register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'PLL Control Register 1'},
#  {'prompt': 'What is the description of PLLM field from PLL_CTL1 register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'PLL Control Register 1'},
#  {'prompt': 'What is the description of PLL_CTL2 register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'PLL Control Register 2'},
#  {'prompt': 'What is the size of PLL_CTL2 register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 8},
#  {'prompt': 'What is the address_offset of PLL_CTL2 register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 60},
#  {'prompt': 'List all the fieldss of PLL_CTL2 register from CRG peripheral for MB9AF31xK microcontroller.',
#   'completion': 'PLLN'},
#  {'prompt': 'What is the description of PLLN field from PLL_CTL2 register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'PLL Control Register 2'},
#  {'prompt': 'What is the description of DBWDT_CTL register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Debug Break Watchdog Timer Control Register'},
#  {'prompt': 'What is the size of DBWDT_CTL register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 8},
#  {'prompt': 'What is the address_offset of DBWDT_CTL register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 84},
#  {'prompt': 'List all the fieldss of DBWDT_CTL register from CRG peripheral for MB9AF31xK microcontroller.',
#   'completion': 'DPHWBE, DPSWBE'},
#  {'prompt': 'What is the description of DPHWBE field from DBWDT_CTL register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Debug Break Watchdog Timer Control Register'},
#  {'prompt': 'What is the description of DPSWBE field from DBWDT_CTL register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Debug Break Watchdog Timer Control Register'},
#  {'prompt': 'What is the description of INT_ENR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': ' Interrupt Enable Register'},
#  {'prompt': 'What is the size of INT_ENR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 8},
#  {'prompt': 'What is the address_offset of INT_ENR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 96},
#  {'prompt': 'List all the fieldss of INT_ENR register from CRG peripheral for MB9AF31xK microcontroller.',
#   'completion': 'FCSE, PCSE, SCSE, MCSE'},
#  {'prompt': 'What is the description of FCSE field from INT_ENR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': ' Interrupt Enable Register'},
#  {'prompt': 'What is the description of PCSE field from INT_ENR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': ' Interrupt Enable Register'},
#  {'prompt': 'What is the description of SCSE field from INT_ENR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': ' Interrupt Enable Register'},
#  {'prompt': 'What is the description of MCSE field from INT_ENR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': ' Interrupt Enable Register'},
#  {'prompt': 'What is the description of INT_STR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Interrupt Status Register'},
#  {'prompt': 'What is the size of INT_STR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 8},
#  {'prompt': 'What is the address_offset of INT_STR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 100},
#  {'prompt': 'List all the fieldss of INT_STR register from CRG peripheral for MB9AF31xK microcontroller.',
#   'completion': 'FCSI, PCSI, SCSI, MCSI'},
#  {'prompt': 'What is the description of FCSI field from INT_STR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Interrupt Status Register'},
#  {'prompt': 'What is the description of PCSI field from INT_STR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Interrupt Status Register'},
#  {'prompt': 'What is the description of SCSI field from INT_STR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Interrupt Status Register'},
#  {'prompt': 'What is the description of MCSI field from INT_STR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Interrupt Status Register'},
#  {'prompt': 'What is the description of INT_CLR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Interrupt Clear Register'},
#  {'prompt': 'What is the size of INT_CLR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 8},
#  {'prompt': 'What is the address_offset of INT_CLR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 104},
#  {'prompt': 'List all the fieldss of INT_CLR register from CRG peripheral for MB9AF31xK microcontroller.',
#   'completion': 'FCSC, PCSC, SCSC, MCSC'},
#  {'prompt': 'What is the description of FCSC field from INT_CLR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Interrupt Clear Register'},
#  {'prompt': 'What is the description of PCSC field from INT_CLR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Interrupt Clear Register'},
#  {'prompt': 'What is the description of SCSC field from INT_CLR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Interrupt Clear Register'},
#  {'prompt': 'What is the description of MCSC field from INT_CLR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Interrupt Clear Register'},
#  {'prompt': 'What is the description of RST_STR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Reset Cause Register'},
#  {'prompt': 'What is the size of RST_STR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 16},
#  {'prompt': 'What is the address_offset of RST_STR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 12},
#  {'prompt': 'List all the fieldss of RST_STR register from CRG peripheral for MB9AF31xK microcontroller.',
#   'completion': 'SRST, FCSR, CSVR, HWDG, SWDG, INITX, PONR'},
#  {'prompt': 'What is the description of SRST field from RST_STR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Reset Cause Register'},
#  {'prompt': 'What is the description of FCSR field from RST_STR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Reset Cause Register'},
#  {'prompt': 'What is the description of CSVR field from RST_STR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Reset Cause Register'},
#  {'prompt': 'What is the description of HWDG field from RST_STR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Reset Cause Register'},
#  {'prompt': 'What is the description of SWDG field from RST_STR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Reset Cause Register'},
#  {'prompt': 'What is the description of INITX field from RST_STR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Reset Cause Register'},
#  {'prompt': 'What is the description of PONR field from RST_STR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Reset Cause Register'},
#  {'prompt': 'What is the description of STB_CTL register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Standby Mode Control Register'},
#  {'prompt': 'What is the size of STB_CTL register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 32},
#  {'prompt': 'What is the address_offset of STB_CTL register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 8},
#  {'prompt': 'List all the fieldss of STB_CTL register from CRG peripheral for MB9AF31xK microcontroller.',
#   'completion': 'KEY, SPL, DSTM, STM'},
#  {'prompt': 'What is the description of KEY field from STB_CTL register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Standby Mode Control Register'},
#  {'prompt': 'What is the description of SPL field from STB_CTL register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Standby Mode Control Register'},
#  {'prompt': 'What is the description of DSTM field from STB_CTL register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Standby Mode Control Register'},
#  {'prompt': 'What is the description of STM field from STB_CTL register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Standby Mode Control Register'},
#  {'prompt': 'What is the description of CSV_CTL register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'CSV control register'},
#  {'prompt': 'What is the size of CSV_CTL register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 16},
#  {'prompt': 'What is the address_offset of CSV_CTL register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 64},
#  {'prompt': 'List all the fieldss of CSV_CTL register from CRG peripheral for MB9AF31xK microcontroller.',
#   'completion': 'FCD, FCSRE, FCSDE, SCSVE, MCSVE'},
#  {'prompt': 'What is the description of FCD field from CSV_CTL register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'CSV control register'},
#  {'prompt': 'What is the description of FCSRE field from CSV_CTL register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'CSV control register'},
#  {'prompt': 'What is the description of FCSDE field from CSV_CTL register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'CSV control register'},
#  {'prompt': 'What is the description of SCSVE field from CSV_CTL register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'CSV control register'},
#  {'prompt': 'What is the description of MCSVE field from CSV_CTL register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'CSV control register'},
#  {'prompt': 'What is the description of CSV_STR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'CSV status register'},
#  {'prompt': 'What is the size of CSV_STR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 8},
#  {'prompt': 'What is the address_offset of CSV_STR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 68},
#  {'prompt': 'List all the fieldss of CSV_STR register from CRG peripheral for MB9AF31xK microcontroller.',
#   'completion': 'SCMF, MCMF'},
#  {'prompt': 'What is the description of SCMF field from CSV_STR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'CSV status register'},
#  {'prompt': 'What is the description of MCMF field from CSV_STR register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'CSV status register'},
#  {'prompt': 'What is the description of FCSWH_CTL register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Frequency detection window setting register'},
#  {'prompt': 'What is the size of FCSWH_CTL register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 16},
#  {'prompt': 'What is the address_offset of FCSWH_CTL register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 72},
#  {'prompt': 'List all the fieldss of FCSWH_CTL register from CRG peripheral for MB9AF31xK microcontroller.',
#   'completion': ''},
#  {'prompt': 'What is the description of FCSWL_CTL register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Frequency detection window setting register'},
#  {'prompt': 'What is the size of FCSWL_CTL register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 16},
#  {'prompt': 'What is the address_offset of FCSWL_CTL register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 76},
#  {'prompt': 'List all the fieldss of FCSWL_CTL register from CRG peripheral for MB9AF31xK microcontroller.',
#   'completion': ''},
#  {'prompt': 'What is the description of FCSWD_CTL register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Frequency detection counter register'},
#  {'prompt': 'What is the size of FCSWD_CTL register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 16},
#  {'prompt': 'What is the address_offset of FCSWD_CTL register from CRG peripheral for MB9AF31xK microcontroller?',
#   'completion': 80},
#  {'prompt': 'List all the fieldss of FCSWD_CTL register from CRG peripheral for MB9AF31xK microcontroller.',
#   'completion': ''},
#  {'prompt': 'What is the description of CRTRIM peripheral for MB9AF31xK microcontroller?',
#   'completion': 'CR Trimming Registers'},
#  {'prompt': 'What is the base address of CRTRIM peripheral for MB9AF31xK microcontroller?',
#   'completion': 1073930240},
#  {'prompt': 'List all the registers of CRTRIM peripheral for MB9AF31xK microcontroller.',
#   'completion': 'MCR_PSR, MCR_FTRM, MCR_RLR'},
#  {'prompt': 'What is the description of MCR_PSR register from CRTRIM peripheral for MB9AF31xK microcontroller?',
#   'completion': 'High-speed CR oscillation Frequency Division Setup Register'},
#  {'prompt': 'What is the size of MCR_PSR register from CRTRIM peripheral for MB9AF31xK microcontroller?',
#   'completion': 8},
#  {'prompt': 'What is the address_offset of MCR_PSR register from CRTRIM peripheral for MB9AF31xK microcontroller?',
#   'completion': 0},
#  {'prompt': 'List all the fieldss of MCR_PSR register from CRTRIM peripheral for MB9AF31xK microcontroller.',
#   'completion': 'CSR'},
#  {'prompt': 'What is the description of CSR field from MCR_PSR register from CRTRIM peripheral for MB9AF31xK microcontroller?',
#   'completion': 'High-speed CR oscillation Frequency Division Setup Register'},
#  {'prompt': 'What is the description of MCR_FTRM register from CRTRIM peripheral for MB9AF31xK microcontroller?',
#   'completion': 'High-speed CR oscillation Frequency Trimming Register'},
#  {'prompt': 'What is the size of MCR_FTRM register from CRTRIM peripheral for MB9AF31xK microcontroller?',
#   'completion': 16},
#  {'prompt': 'What is the address_offset of MCR_FTRM register from CRTRIM peripheral for MB9AF31xK microcontroller?',
#   'completion': 4},
#  {'prompt': 'List all the fieldss of MCR_FTRM register from CRTRIM peripheral for MB9AF31xK microcontroller.',
#   'completion': 'TRD'},
#  {'prompt': 'What is the description of TRD field from MCR_FTRM register from CRTRIM peripheral for MB9AF31xK microcontroller?',
#   'completion': 'High-speed CR oscillation Frequency Trimming Register'},
#  {'prompt': 'What is the description of MCR_RLR register from CRTRIM peripheral for MB9AF31xK microcontroller?',
#   'completion': 'High-Speed CR Oscillation Register Write-Protect Register '},
#  {'prompt': 'What is the size of MCR_RLR register from CRTRIM peripheral for MB9AF31xK microcontroller?',
#   'completion': 32},
#  {'prompt': 'What is the address_offset of MCR_RLR register from CRTRIM peripheral for MB9AF31xK microcontroller?',
#   'completion': 12},
#  {'prompt': 'List all the fieldss of MCR_RLR register from CRTRIM peripheral for MB9AF31xK microcontroller.',
#   'completion': 'TRMLCK'},
#  {'prompt': 'What is the description of TRMLCK field from MCR_RLR register from CRTRIM peripheral for MB9AF31xK microcontroller?',
#   'completion': 'High-Speed CR Oscillation Register Write-Protect Register '},
#  {'prompt': 'What is the description of SWWDT peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Software Watchdog Timer'},
#  {'prompt': 'What is the base address of SWWDT peripheral for MB9AF31xK microcontroller?',
#   'completion': 1073815552},
#  {'prompt': 'List all the registers of SWWDT peripheral for MB9AF31xK microcontroller.',
#   'completion': 'WDOGLOAD, WDOGVALUE, WDOGCONTROL, WDOGINTCLR, WDOGRIS, WDOGLOCK'},
#  {'prompt': 'What is the description of WDOGLOAD register from SWWDT peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Software Watchdog Timer Load Register'},
#  {'prompt': 'What is the size of WDOGLOAD register from SWWDT peripheral for MB9AF31xK microcontroller?',
#   'completion': 32},
#  {'prompt': 'What is the address_offset of WDOGLOAD register from SWWDT peripheral for MB9AF31xK microcontroller?',
#   'completion': 0},
#  {'prompt': 'List all the fieldss of WDOGLOAD register from SWWDT peripheral for MB9AF31xK microcontroller.',
#   'completion': ''},
#  {'prompt': 'What is the description of WDOGVALUE register from SWWDT peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Software Watchdog Timer Value Register'},
#  {'prompt': 'What is the size of WDOGVALUE register from SWWDT peripheral for MB9AF31xK microcontroller?',
#   'completion': 32},
#  {'prompt': 'What is the address_offset of WDOGVALUE register from SWWDT peripheral for MB9AF31xK microcontroller?',
#   'completion': 4},
#  {'prompt': 'List all the fieldss of WDOGVALUE register from SWWDT peripheral for MB9AF31xK microcontroller.',
#   'completion': ''},
#  {'prompt': 'What is the description of WDOGCONTROL register from SWWDT peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Software Watchdog Timer Control Register'},
#  {'prompt': 'What is the size of WDOGCONTROL register from SWWDT peripheral for MB9AF31xK microcontroller?',
#   'completion': 8},
#  {'prompt': 'What is the address_offset of WDOGCONTROL register from SWWDT peripheral for MB9AF31xK microcontroller?',
#   'completion': 8},
#  {'prompt': 'List all the fieldss of WDOGCONTROL register from SWWDT peripheral for MB9AF31xK microcontroller.',
#   'completion': 'RESEN, INTEN'},
#  {'prompt': 'What is the description of RESEN field from WDOGCONTROL register from SWWDT peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Software Watchdog Timer Control Register'},
#  {'prompt': 'What is the description of INTEN field from WDOGCONTROL register from SWWDT peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Software Watchdog Timer Control Register'},
#  {'prompt': 'What is the description of WDOGINTCLR register from SWWDT peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Software Watchdog Timer Clear Register'},
#  {'prompt': 'What is the size of WDOGINTCLR register from SWWDT peripheral for MB9AF31xK microcontroller?',
#   'completion': 32},
#  {'prompt': 'What is the address_offset of WDOGINTCLR register from SWWDT peripheral for MB9AF31xK microcontroller?',
#   'completion': 12},
#  {'prompt': 'List all the fieldss of WDOGINTCLR register from SWWDT peripheral for MB9AF31xK microcontroller.',
#   'completion': ''},
#  {'prompt': 'What is the description of WDOGRIS register from SWWDT peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Software Watchdog Timer Interrupt Status Register'},
#  {'prompt': 'What is the size of WDOGRIS register from SWWDT peripheral for MB9AF31xK microcontroller?',
#   'completion': 8},
#  {'prompt': 'What is the address_offset of WDOGRIS register from SWWDT peripheral for MB9AF31xK microcontroller?',
#   'completion': 16},
#  {'prompt': 'List all the fieldss of WDOGRIS register from SWWDT peripheral for MB9AF31xK microcontroller.',
#   'completion': 'RIS'},
#  {'prompt': 'What is the description of RIS field from WDOGRIS register from SWWDT peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Software Watchdog Timer Interrupt Status Register'},
#  {'prompt': 'What is the description of WDOGLOCK register from SWWDT peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Software Watchdog Timer Lock Register'},
#  {'prompt': 'What is the size of WDOGLOCK register from SWWDT peripheral for MB9AF31xK microcontroller?',
#   'completion': 32},
#  {'prompt': 'What is the address_offset of WDOGLOCK register from SWWDT peripheral for MB9AF31xK microcontroller?',
#   'completion': 3072},
#  {'prompt': 'List all the fieldss of WDOGLOCK register from SWWDT peripheral for MB9AF31xK microcontroller.',
#   'completion': ''},
#  {'prompt': 'What is the description of HWWDT peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Hardware Watchdog Timer'},
#  {'prompt': 'What is the base address of HWWDT peripheral for MB9AF31xK microcontroller?',
#   'completion': 1073811456},
#  {'prompt': 'List all the registers of HWWDT peripheral for MB9AF31xK microcontroller.',
#   'completion': 'WDG_LDR, WDG_VLR, WDG_CTL, WDG_ICL, WDG_RIS, WDG_LCK'},
#  {'prompt': 'What is the description of WDG_LDR register from HWWDT peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Hardware Watchdog Timer Load Register'},
#  {'prompt': 'What is the size of WDG_LDR register from HWWDT peripheral for MB9AF31xK microcontroller?',
#   'completion': 32},
#  {'prompt': 'What is the address_offset of WDG_LDR register from HWWDT peripheral for MB9AF31xK microcontroller?',
#   'completion': 0},
#  {'prompt': 'List all the fieldss of WDG_LDR register from HWWDT peripheral for MB9AF31xK microcontroller.',
#   'completion': ''},
#  {'prompt': 'What is the description of WDG_VLR register from HWWDT peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Hardware Watchdog Timer Value Register'},
#  {'prompt': 'What is the size of WDG_VLR register from HWWDT peripheral for MB9AF31xK microcontroller?',
#   'completion': 32},
#  {'prompt': 'What is the address_offset of WDG_VLR register from HWWDT peripheral for MB9AF31xK microcontroller?',
#   'completion': 4},
#  {'prompt': 'List all the fieldss of WDG_VLR register from HWWDT peripheral for MB9AF31xK microcontroller.',
#   'completion': ''},
#  {'prompt': 'What is the description of WDG_CTL register from HWWDT peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Hardware Watchdog Timer Control Register'},
#  {'prompt': 'What is the size of WDG_CTL register from HWWDT peripheral for MB9AF31xK microcontroller?',
#   'completion': 32},
#  {'prompt': 'What is the address_offset of WDG_CTL register from HWWDT peripheral for MB9AF31xK microcontroller?',
#   'completion': 8},
#  {'prompt': 'List all the fieldss of WDG_CTL register from HWWDT peripheral for MB9AF31xK microcontroller.',
#   'completion': 'RESEN, INTEN'},
#  {'prompt': 'What is the description of RESEN field from WDG_CTL register from HWWDT peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Hardware Watchdog Timer Control Register'},
#  {'prompt': 'What is the description of INTEN field from WDG_CTL register from HWWDT peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Hardware Watchdog Timer Control Register'},
#  {'prompt': 'What is the description of WDG_ICL register from HWWDT peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Hardware Watchdog Timer Clear Register'},
#  {'prompt': 'What is the size of WDG_ICL register from HWWDT peripheral for MB9AF31xK microcontroller?',
#   'completion': 8},
#  {'prompt': 'What is the address_offset of WDG_ICL register from HWWDT peripheral for MB9AF31xK microcontroller?',
#   'completion': 12},
#  {'prompt': 'List all the fieldss of WDG_ICL register from HWWDT peripheral for MB9AF31xK microcontroller.',
#   'completion': ''},
#  {'prompt': 'What is the description of WDG_RIS register from HWWDT peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Hardware Watchdog Timer Interrupt Status Register'},
#  {'prompt': 'What is the size of WDG_RIS register from HWWDT peripheral for MB9AF31xK microcontroller?',
#   'completion': 1},
#  {'prompt': 'What is the address_offset of WDG_RIS register from HWWDT peripheral for MB9AF31xK microcontroller?',
#   'completion': 16},
#  {'prompt': 'List all the fieldss of WDG_RIS register from HWWDT peripheral for MB9AF31xK microcontroller.',
#   'completion': 'RIS'},
#  {'prompt': 'What is the description of RIS field from WDG_RIS register from HWWDT peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Hardware Watchdog Timer Interrupt Status Register'},
#  {'prompt': 'What is the description of WDG_LCK register from HWWDT peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Hardware Watchdog Timer Lock Register'},
#  {'prompt': 'What is the size of WDG_LCK register from HWWDT peripheral for MB9AF31xK microcontroller?',
#   'completion': 32},
#  {'prompt': 'What is the address_offset of WDG_LCK register from HWWDT peripheral for MB9AF31xK microcontroller?',
#   'completion': 3072},
#  {'prompt': 'List all the fieldss of WDG_LCK register from HWWDT peripheral for MB9AF31xK microcontroller.',
#   'completion': ''},
#  {'prompt': 'What is the description of DTIM peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Dual Timer'},
#  {'prompt': 'What is the base address of DTIM peripheral for MB9AF31xK microcontroller?',
#   'completion': 1073827840},
#  {'prompt': 'List all the registers of DTIM peripheral for MB9AF31xK microcontroller.',
#   'completion': 'TIMER1LOAD, TIMER1VALUE, TIMER1CONTROL, TIMER1INTCLR, TIMER1RIS, TIMER1MIS, TIMER1BGLOAD, TIMER2LOAD, TIMER2VALUE, TIMER2CONTROL, TIMER2INTCLR, TIMER2RIS, TIMER2MIS, TIMER2BGLOAD'},
#  {'prompt': 'What is the description of TIMER1LOAD register from DTIM peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Load Register'},
#  {'prompt': 'What is the size of TIMER1LOAD register from DTIM peripheral for MB9AF31xK microcontroller?',
#   'completion': 32},
#  {'prompt': 'What is the address_offset of TIMER1LOAD register from DTIM peripheral for MB9AF31xK microcontroller?',
#   'completion': 0},
#  {'prompt': 'List all the fieldss of TIMER1LOAD register from DTIM peripheral for MB9AF31xK microcontroller.',
#   'completion': ''},
#  {'prompt': 'What is the description of TIMER1VALUE register from DTIM peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Value Register'},
#  {'prompt': 'What is the size of TIMER1VALUE register from DTIM peripheral for MB9AF31xK microcontroller?',
#   'completion': 32},
#  {'prompt': 'What is the address_offset of TIMER1VALUE register from DTIM peripheral for MB9AF31xK microcontroller?',
#   'completion': 4},
#  {'prompt': 'List all the fieldss of TIMER1VALUE register from DTIM peripheral for MB9AF31xK microcontroller.',
#   'completion': ''},
#  {'prompt': 'What is the description of TIMER1CONTROL register from DTIM peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Control Register'},
#  {'prompt': 'What is the size of TIMER1CONTROL register from DTIM peripheral for MB9AF31xK microcontroller?',
#   'completion': 32},
#  {'prompt': 'What is the address_offset of TIMER1CONTROL register from DTIM peripheral for MB9AF31xK microcontroller?',
#   'completion': 8},
#  {'prompt': 'List all the fieldss of TIMER1CONTROL register from DTIM peripheral for MB9AF31xK microcontroller.',
#   'completion': 'TimerEn, TimerMode, IntEnable, TimerPre, TimerSize, OneShot'},
#  {'prompt': 'What is the description of TimerEn field from TIMER1CONTROL register from DTIM peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Control Register'},
#  {'prompt': 'What is the description of TimerMode field from TIMER1CONTROL register from DTIM peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Control Register'},
#  {'prompt': 'What is the description of IntEnable field from TIMER1CONTROL register from DTIM peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Control Register'},
#  {'prompt': 'What is the description of TimerPre field from TIMER1CONTROL register from DTIM peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Control Register'},
#  {'prompt': 'What is the description of TimerSize field from TIMER1CONTROL register from DTIM peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Control Register'},
#  {'prompt': 'What is the description of OneShot field from TIMER1CONTROL register from DTIM peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Control Register'},
#  {'prompt': 'What is the description of TIMER1INTCLR register from DTIM peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Interrupt Clear Register'},
#  {'prompt': 'What is the size of TIMER1INTCLR register from DTIM peripheral for MB9AF31xK microcontroller?',
#   'completion': 32},
#  {'prompt': 'What is the address_offset of TIMER1INTCLR register from DTIM peripheral for MB9AF31xK microcontroller?',
#   'completion': 12},
#  {'prompt': 'List all the fieldss of TIMER1INTCLR register from DTIM peripheral for MB9AF31xK microcontroller.',
#   'completion': ''},
#  {'prompt': 'What is the description of TIMER1RIS register from DTIM peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Interrupt Status Register'},
#  {'prompt': 'What is the size of TIMER1RIS register from DTIM peripheral for MB9AF31xK microcontroller?',
#   'completion': 32},
#  {'prompt': 'What is the address_offset of TIMER1RIS register from DTIM peripheral for MB9AF31xK microcontroller?',
#   'completion': 16},
#  {'prompt': 'List all the fieldss of TIMER1RIS register from DTIM peripheral for MB9AF31xK microcontroller.',
#   'completion': 'TIMER1RIS'},
#  {'prompt': 'What is the description of TIMER1RIS field from TIMER1RIS register from DTIM peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Interrupt Status Register'},
#  {'prompt': 'What is the description of TIMER1MIS register from DTIM peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Masked Interrupt Status Register'},
#  {'prompt': 'What is the size of TIMER1MIS register from DTIM peripheral for MB9AF31xK microcontroller?',
#   'completion': 32},
# ...
#   'completion': 'Timer Control Register'},
#  {'prompt': 'What is the description of STRG field from PPG_TMCR register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Timer Control Register'},
#  {'prompt': 'What is the description of PPG_TMCR2 register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Timer Control Register 2'},
#  {'prompt': 'What is the size of PPG_TMCR2 register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 8},
#  {'prompt': 'What is the address_offset of PPG_TMCR2 register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 17},
#  {'prompt': 'List all the fieldss of PPG_TMCR2 register from BT1 peripheral for MB9AF31xK microcontroller.',
#   'completion': 'CKS3'},
#  {'prompt': 'What is the description of CKS3 field from PPG_TMCR2 register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Timer Control Register 2'},
#  {'prompt': 'What is the description of PPG_STC register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Status Control Register'},
#  {'prompt': 'What is the size of PPG_STC register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 8},
#  {'prompt': 'What is the address_offset of PPG_STC register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 16},
#  {'prompt': 'List all the fieldss of PPG_STC register from BT1 peripheral for MB9AF31xK microcontroller.',
#   'completion': 'TGIE, UDIE, TGIR, UDIR'},
#  {'prompt': 'What is the description of TGIE field from PPG_STC register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Status Control Register'},
#  {'prompt': 'What is the description of UDIE field from PPG_STC register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Status Control Register'},
#  {'prompt': 'What is the description of TGIR field from PPG_STC register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Status Control Register'},
#  {'prompt': 'What is the description of UDIR field from PPG_STC register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Status Control Register'},
#  {'prompt': 'What is the description of PPG_PRLL register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 'LOW Width Reload Register'},
#  {'prompt': 'What is the size of PPG_PRLL register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 16},
#  {'prompt': 'What is the address_offset of PPG_PRLL register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 0},
#  {'prompt': 'List all the fieldss of PPG_PRLL register from BT1 peripheral for MB9AF31xK microcontroller.',
#   'completion': ''},
#  {'prompt': 'What is the description of PPG_PRLH register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 'HIGH Width Reload Register'},
#  {'prompt': 'What is the size of PPG_PRLH register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 16},
#  {'prompt': 'What is the address_offset of PPG_PRLH register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 4},
#  {'prompt': 'List all the fieldss of PPG_PRLH register from BT1 peripheral for MB9AF31xK microcontroller.',
#   'completion': ''},
#  {'prompt': 'What is the description of PPG_TMR register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Timer Register'},
#  {'prompt': 'What is the size of PPG_TMR register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 16},
#  {'prompt': 'What is the address_offset of PPG_TMR register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 8},
#  {'prompt': 'List all the fieldss of PPG_TMR register from BT1 peripheral for MB9AF31xK microcontroller.',
#   'completion': ''},
#  {'prompt': 'What is the description of RT_TMCR register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Timer Control Register'},
#  {'prompt': 'What is the size of RT_TMCR register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 16},
#  {'prompt': 'What is the address_offset of RT_TMCR register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 12},
#  {'prompt': 'List all the fieldss of RT_TMCR register from BT1 peripheral for MB9AF31xK microcontroller.',
#   'completion': 'CKS2_0, EGS, T32, FMD, OSEL, MDSE, CTEN, STRG'},
#  {'prompt': 'What is the description of CKS2_0 field from RT_TMCR register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Timer Control Register'},
#  {'prompt': 'What is the description of EGS field from RT_TMCR register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Timer Control Register'},
#  {'prompt': 'What is the description of T32 field from RT_TMCR register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Timer Control Register'},
#  {'prompt': 'What is the description of FMD field from RT_TMCR register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Timer Control Register'},
#  {'prompt': 'What is the description of OSEL field from RT_TMCR register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Timer Control Register'},
#  {'prompt': 'What is the description of MDSE field from RT_TMCR register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Timer Control Register'},
#  {'prompt': 'What is the description of CTEN field from RT_TMCR register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Timer Control Register'},
#  {'prompt': 'What is the description of STRG field from RT_TMCR register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Timer Control Register'},
#  {'prompt': 'What is the description of RT_TMCR2 register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Timer Control Register 2'},
#  {'prompt': 'What is the size of RT_TMCR2 register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 8},
#  {'prompt': 'What is the address_offset of RT_TMCR2 register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 17},
#  {'prompt': 'List all the fieldss of RT_TMCR2 register from BT1 peripheral for MB9AF31xK microcontroller.',
#   'completion': 'CKS3'},
#  {'prompt': 'What is the description of CKS3 field from RT_TMCR2 register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Timer Control Register 2'},
#  {'prompt': 'What is the description of RT_STC register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Status Control Register'},
#  {'prompt': 'What is the size of RT_STC register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 8},
#  {'prompt': 'What is the address_offset of RT_STC register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 16},
#  {'prompt': 'List all the fieldss of RT_STC register from BT1 peripheral for MB9AF31xK microcontroller.',
#   'completion': 'TGIE, UDIE, TGIR, UDIR'},
#  {'prompt': 'What is the description of TGIE field from RT_STC register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Status Control Register'},
#  {'prompt': 'What is the description of UDIE field from RT_STC register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Status Control Register'},
#  {'prompt': 'What is the description of TGIR field from RT_STC register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Status Control Register'},
#  {'prompt': 'What is the description of UDIR field from RT_STC register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Status Control Register'},
#  {'prompt': 'What is the description of RT_PCSR register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 'PWM Cycle Set Register'},
#  {'prompt': 'What is the size of RT_PCSR register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 16},
#  {'prompt': 'What is the address_offset of RT_PCSR register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 0},
#  {'prompt': 'List all the fieldss of RT_PCSR register from BT1 peripheral for MB9AF31xK microcontroller.',
#   'completion': ''},
#  {'prompt': 'What is the description of RT_TMR register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Timer Register'},
#  {'prompt': 'What is the size of RT_TMR register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 16},
#  {'prompt': 'What is the address_offset of RT_TMR register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 8},
#  {'prompt': 'List all the fieldss of RT_TMR register from BT1 peripheral for MB9AF31xK microcontroller.',
#   'completion': ''},
#  {'prompt': 'What is the description of PWC_TMCR register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Timer Control Register'},
#  {'prompt': 'What is the size of PWC_TMCR register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 16},
#  {'prompt': 'What is the address_offset of PWC_TMCR register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 12},
#  {'prompt': 'List all the fieldss of PWC_TMCR register from BT1 peripheral for MB9AF31xK microcontroller.',
#   'completion': 'CKS2_0, EGS, T32, FMD, MDSE, CTEN'},
#  {'prompt': 'What is the description of CKS2_0 field from PWC_TMCR register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Timer Control Register'},
#  {'prompt': 'What is the description of EGS field from PWC_TMCR register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Timer Control Register'},
#  {'prompt': 'What is the description of T32 field from PWC_TMCR register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Timer Control Register'},
#  {'prompt': 'What is the description of FMD field from PWC_TMCR register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Timer Control Register'},
#  {'prompt': 'What is the description of MDSE field from PWC_TMCR register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Timer Control Register'},
#  {'prompt': 'What is the description of CTEN field from PWC_TMCR register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Timer Control Register'},
#  {'prompt': 'What is the description of PWC_TMCR2 register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Timer Control Register 2'},
#  {'prompt': 'What is the size of PWC_TMCR2 register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 8},
#  {'prompt': 'What is the address_offset of PWC_TMCR2 register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 17},
#  {'prompt': 'List all the fieldss of PWC_TMCR2 register from BT1 peripheral for MB9AF31xK microcontroller.',
#   'completion': 'CKS3'},
#  {'prompt': 'What is the description of CKS3 field from PWC_TMCR2 register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Timer Control Register 2'},
#  {'prompt': 'What is the description of PWC_STC register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Status Control Register'},
#  {'prompt': 'What is the size of PWC_STC register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 8},
#  {'prompt': 'What is the address_offset of PWC_STC register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 16},
#  {'prompt': 'List all the fieldss of PWC_STC register from BT1 peripheral for MB9AF31xK microcontroller.',
#   'completion': 'ERR, EDIE, OVIE, EDIR, OVIR'},
#  {'prompt': 'What is the description of ERR field from PWC_STC register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Status Control Register'},
#  {'prompt': 'What is the description of EDIE field from PWC_STC register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Status Control Register'},
#  {'prompt': 'What is the description of OVIE field from PWC_STC register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Status Control Register'},
#  {'prompt': 'What is the description of EDIR field from PWC_STC register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Status Control Register'},
#  {'prompt': 'What is the description of OVIR field from PWC_STC register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Status Control Register'},
#  {'prompt': 'What is the description of PWC_DTBF register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Data Buffer Register'},
#  {'prompt': 'What is the size of PWC_DTBF register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 16},
#  {'prompt': 'What is the address_offset of PWC_DTBF register from BT1 peripheral for MB9AF31xK microcontroller?',
#   'completion': 4},
#  {'prompt': 'List all the fieldss of PWC_DTBF register from BT1 peripheral for MB9AF31xK microcontroller.',
#   'completion': ''},
#  {'prompt': 'What is the description of BT2 peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Base Timer 0'},
#  {'prompt': 'What is the base address of BT2 peripheral for MB9AF31xK microcontroller?',
#   'completion': 1073893504},
#  {'prompt': 'List all the registers of BT2 peripheral for MB9AF31xK microcontroller.',
#   'completion': 'PWM_TMCR, PWM_TMCR2, PWM_STC, PWM_PCSR, PWM_PDUT, PWM_TMR, PPG_TMCR, PPG_TMCR2, PPG_STC, PPG_PRLL, PPG_PRLH, PPG_TMR, RT_TMCR, RT_TMCR2, RT_STC, RT_PCSR, RT_TMR, PWC_TMCR, PWC_TMCR2, PWC_STC, PWC_DTBF'},
#  {'prompt': 'What is the description of PWM_TMCR register from BT2 peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Timer Control Register'},
#  {'prompt': 'What is the size of PWM_TMCR register from BT2 peripheral for MB9AF31xK microcontroller?',
#   'completion': 16},
#  {'prompt': 'What is the address_offset of PWM_TMCR register from BT2 peripheral for MB9AF31xK microcontroller?',
#   'completion': 12},
#  {'prompt': 'List all the fieldss of PWM_TMCR register from BT2 peripheral for MB9AF31xK microcontroller.',
#   'completion': 'CKS2_0, RTGEN, PMSK, EGS, FMD, OSEL, MDSE, CTEN, STRG'},
#  {'prompt': 'What is the description of CKS2_0 field from PWM_TMCR register from BT2 peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Timer Control Register'},
#  {'prompt': 'What is the description of RTGEN field from PWM_TMCR register from BT2 peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Timer Control Register'},
#  {'prompt': 'What is the description of PMSK field from PWM_TMCR register from BT2 peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Timer Control Register'},
#  {'prompt': 'What is the description of EGS field from PWM_TMCR register from BT2 peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Timer Control Register'},
#  {'prompt': 'What is the description of FMD field from PWM_TMCR register from BT2 peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Timer Control Register'},
#  {'prompt': 'What is the description of OSEL field from PWM_TMCR register from BT2 peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Timer Control Register'},
#  {'prompt': 'What is the description of MDSE field from PWM_TMCR register from BT2 peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Timer Control Register'},
#  {'prompt': 'What is the description of CTEN field from PWM_TMCR register from BT2 peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Timer Control Register'},
#  {'prompt': 'What is the description of STRG field from PWM_TMCR register from BT2 peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Timer Control Register'},
#  {'prompt': 'What is the description of PWM_TMCR2 register from BT2 peripheral for MB9AF31xK microcontroller?',
#   'completion': 'Timer Control Register 2'},
#  {'prompt': 'What is the size of PWM_TMCR2 register from BT2 peripheral for MB9AF31xK microcontroller?',
#   'completion': 8},
#  ...]
